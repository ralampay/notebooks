# %%
import pandas as pd
import json
from numerapi import NumerAPI
import gc

# %%
napi = NumerAPI()
current_round = napi.get_current_round(tournament=8)
print("Current round: {}".format(current_round))
# Out:
# Current round: 299

# %%
print("Downloading dataset files...")
napi.download_dataset("numerai_training_data.parquet", "training_data.parquet")
napi.download_dataset("numerai_tournament_data.parquet", f"tournament_data_{current_round}.parquet")
napi.download_dataset("numerai_validation_data.parquet", f"validation_data.parquet")
napi.download_dataset("features.json", "features.json")
# Out:
# Downloading dataset files...
# 2022-01-19 00:46:23,716 INFO numerapi.utils: target file already exists
# 2022-01-19 00:46:23,717 INFO numerapi.utils: download complete
# 2022-01-19 00:46:25,464 INFO numerapi.utils: target file already exists
# 2022-01-19 00:46:25,465 INFO numerapi.utils: download complete
# 2022-01-19 00:46:27,085 INFO numerapi.utils: target file already exists
# 2022-01-19 00:46:27,086 INFO numerapi.utils: download complete
# 2022-01-19 00:46:28,788 INFO numerapi.utils: target file already exists
# 2022-01-19 00:46:28,789 INFO numerapi.utils: download complete

# %%
ERA_COL = "era"
TARGET_COL = "target_nomi_20"
DATA_TYPE_COL = "data_type"

print('Reading minimal training data')
# read the feature metadata amd get the "small" feature set
with open("features.json", "r") as f:
    feature_metadata = json.load(f)
features = feature_metadata["feature_sets"]["small"]
# read in just those features along with era and target columns
read_columns = features + [ERA_COL, DATA_TYPE_COL, TARGET_COL]

print(read_columns)
# Out:
# Reading minimal training data
# ['feature_agile_unrespited_gaucho', 'feature_antichristian_slangiest_idyllist', 'feature_apomictical_motorized_vaporisation', 'feature_assenting_darn_arthropod', 'feature_beery_somatologic_elimination', 'feature_bhutan_imagism_dolerite', 'feature_branched_dilatory_sunbelt', 'feature_buxom_curtained_sienna', 'feature_cambial_bigoted_bacterioid', 'feature_canalicular_peeling_lilienthal', 'feature_chuffier_analectic_conchiolin', 'feature_communicatory_unrecommended_velure', 'feature_crowning_frustrate_kampala', 'feature_exorbitant_myeloid_crinkle', 'feature_flintier_enslaved_borsch', 'feature_glare_factional_assessment', 'feature_grandmotherly_circumnavigable_homonymity', 'feature_gullable_sanguine_incongruity', 'feature_haziest_lifelike_horseback', 'feature_introvert_symphysial_assegai', 'feature_jerkwater_eustatic_electrocardiograph', 'feature_lofty_acceptable_challenge', 'feature_moralistic_heartier_typhoid', 'feature_planned_superimposed_bend', 'feature_silver_handworked_scauper', 'feature_slack_calefacient_tableau', 'feature_store_apteral_isocheim', 'feature_stylistic_honduran_comprador', 'feature_travelled_semipermeable_perruquier', 'feature_twisty_adequate_minutia', 'feature_unaired_operose_lactoprotein', 'feature_undivorced_unsatisfying_praetorium', 'feature_unforbidden_highbrow_kafir', 'feature_univalve_abdicant_distrail', 'feature_unsealed_suffixal_babar', 'feature_unvaried_social_bangkok', 'feature_unwonted_trusted_fixative', 'feature_winsome_irreproachable_milkfish', 'era', 'data_type', 'target_nomi_20']

# %%
# note: sometimes when trying to read the downloaded data you get an error about invalid magic parquet bytes...
# if so, delete the file and rerun the napi.download_dataset to fix the corrupted file
training_data = pd.read_parquet('training_data.parquet', columns=read_columns)

training_data
# Out:
#                   feature_agile_unrespited_gaucho  \
# id
# n003bba8a98662e4                             0.75
# n003bee128c2fcfc                             0.50
# n0048ac83aff7194                             0.50
# n00691bec80d3e02                             0.50
# n00b8720a2fdc4f2                             0.00
# ...                                           ...
# nffcc1dbdf2212e6                             1.00
# nffd71b7f6a128df                             0.00
# nffde3b371d67394                             0.75
# nfff1a1111b35e84                             0.50
# nfff2bd38e397265                             0.75
#
#                   feature_antichristian_slangiest_idyllist  \
# id
# n003bba8a98662e4                                      1.00
# n003bee128c2fcfc                                      0.25
# n0048ac83aff7194                                      0.75
# n00691bec80d3e02                                      0.25
# n00b8720a2fdc4f2                                      1.00
# ...                                                    ...
# nffcc1dbdf2212e6                                      1.00
# nffd71b7f6a128df                                      0.50
# nffde3b371d67394                                      1.00
# nfff1a1111b35e84                                      0.00
# nfff2bd38e397265                                      1.00
#
#                   feature_apomictical_motorized_vaporisation  \
# id
# n003bba8a98662e4                                        0.50
# n003bee128c2fcfc                                        0.50
# n0048ac83aff7194                                        1.00
# n00691bec80d3e02                                        0.50
# n00b8720a2fdc4f2                                        0.25
# ...                                                      ...
# nffcc1dbdf2212e6                                        1.00
# nffd71b7f6a128df                                        0.25
# nffde3b371d67394                                        1.00
# nfff1a1111b35e84                                        0.00
# nfff2bd38e397265                                        1.00
#
#                   feature_assenting_darn_arthropod  \
# id
# n003bba8a98662e4                              0.25
# n003bee128c2fcfc                              0.75
# n0048ac83aff7194                              0.75
# n00691bec80d3e02                              0.50
# n00b8720a2fdc4f2                              1.00
# ...                                            ...
# nffcc1dbdf2212e6                              0.50
# nffd71b7f6a128df                              0.25
# nffde3b371d67394                              1.00
# nfff1a1111b35e84                              1.00
# nfff2bd38e397265                              0.00
#
#                   feature_beery_somatologic_elimination  \
# id
# n003bba8a98662e4                                   1.00
# n003bee128c2fcfc                                   0.50
# n0048ac83aff7194                                   0.75
# n00691bec80d3e02                                   0.00
# n00b8720a2fdc4f2                                   0.00
# ...                                                 ...
# nffcc1dbdf2212e6                                   1.00
# nffd71b7f6a128df                                   1.00
# nffde3b371d67394                                   0.00
# nfff1a1111b35e84                                   0.50
# nfff2bd38e397265                                   0.75
#
#                   feature_bhutan_imagism_dolerite  \
# id
# n003bba8a98662e4                             0.00
# n003bee128c2fcfc                             0.25
# n0048ac83aff7194                             1.00
# n00691bec80d3e02                             0.75
# n00b8720a2fdc4f2                             0.00
# ...                                           ...
# nffcc1dbdf2212e6                             1.00
# nffd71b7f6a128df                             0.50
# nffde3b371d67394                             1.00
# nfff1a1111b35e84                             0.25
# nfff2bd38e397265                             1.00
#
#                   feature_branched_dilatory_sunbelt  \
# id
# n003bba8a98662e4                               0.50
# n003bee128c2fcfc                               0.75
# n0048ac83aff7194                               0.75
# n00691bec80d3e02                               0.00
# n00b8720a2fdc4f2                               0.25
# ...                                             ...
# nffcc1dbdf2212e6                               1.00
# nffd71b7f6a128df                               0.00
# nffde3b371d67394                               1.00
# nfff1a1111b35e84                               1.00
# nfff2bd38e397265                               0.75
#
#                   feature_buxom_curtained_sienna  \
# id
# n003bba8a98662e4                            0.50
# n003bee128c2fcfc                            0.75
# n0048ac83aff7194                            0.75
# n00691bec80d3e02                            0.00
# n00b8720a2fdc4f2                            0.25
# ...                                          ...
# nffcc1dbdf2212e6                            1.00
# nffd71b7f6a128df                            0.25
# nffde3b371d67394                            1.00
# nfff1a1111b35e84                            1.00
# nfff2bd38e397265                            0.50
#
#                   feature_cambial_bigoted_bacterioid  \
# id
# n003bba8a98662e4                                0.00
# n003bee128c2fcfc                                0.25
# n0048ac83aff7194                                0.75
# n00691bec80d3e02                                0.50
# n00b8720a2fdc4f2                                0.75
# ...                                              ...
# nffcc1dbdf2212e6                                0.50
# nffd71b7f6a128df                                0.75
# nffde3b371d67394                                0.50
# nfff1a1111b35e84                                0.25
# nfff2bd38e397265                                0.25
#
#                   feature_canalicular_peeling_lilienthal  ...  \
# id                                                        ...
# n003bba8a98662e4                                    0.75  ...
# n003bee128c2fcfc                                    0.25  ...
# n0048ac83aff7194                                    0.75  ...
# n00691bec80d3e02                                    0.50  ...
# n00b8720a2fdc4f2                                    0.25  ...
# ...                                                  ...  ...
# nffcc1dbdf2212e6                                    1.00  ...
# nffd71b7f6a128df                                    0.00  ...
# nffde3b371d67394                                    1.00  ...
# nfff1a1111b35e84                                    0.00  ...
# nfff2bd38e397265                                    1.00  ...
#
#                   feature_undivorced_unsatisfying_praetorium  \
# id
# n003bba8a98662e4                                        0.50
# n003bee128c2fcfc                                        0.75
# n0048ac83aff7194                                        1.00
# n00691bec80d3e02                                        0.00
# n00b8720a2fdc4f2                                        0.50
# ...                                                      ...
# nffcc1dbdf2212e6                                        0.75
# nffd71b7f6a128df                                        0.00
# nffde3b371d67394                                        0.00
# nfff1a1111b35e84                                        0.25
# nfff2bd38e397265                                        0.00
#
#                   feature_unforbidden_highbrow_kafir  \
# id
# n003bba8a98662e4                                0.00
# n003bee128c2fcfc                                0.25
# n0048ac83aff7194                                1.00
# n00691bec80d3e02                                0.75
# n00b8720a2fdc4f2                                0.00
# ...                                              ...
# nffcc1dbdf2212e6                                1.00
# nffd71b7f6a128df                                1.00
# nffde3b371d67394                                0.25
# nfff1a1111b35e84                                0.00
# nfff2bd38e397265                                1.00
#
#                   feature_univalve_abdicant_distrail  \
# id
# n003bba8a98662e4                                0.00
# n003bee128c2fcfc                                0.75
# n0048ac83aff7194                                0.00
# n00691bec80d3e02                                0.00
# n00b8720a2fdc4f2                                0.00
# ...                                              ...
# nffcc1dbdf2212e6                                0.50
# nffd71b7f6a128df                                0.00
# nffde3b371d67394                                0.50
# nfff1a1111b35e84                                0.25
# nfff2bd38e397265                                0.00
#
#                   feature_unsealed_suffixal_babar  \
# id
# n003bba8a98662e4                             0.50
# n003bee128c2fcfc                             0.50
# n0048ac83aff7194                             0.75
# n00691bec80d3e02                             0.25
# n00b8720a2fdc4f2                             0.00
# ...                                           ...
# nffcc1dbdf2212e6                             0.75
# nffd71b7f6a128df                             0.00
# nffde3b371d67394                             0.75
# nfff1a1111b35e84                             0.50
# nfff2bd38e397265                             0.75
#
#                   feature_unvaried_social_bangkok  \
# id
# n003bba8a98662e4                             0.25
# n003bee128c2fcfc                             1.00
# n0048ac83aff7194                             1.00
# n00691bec80d3e02                             0.00
# n00b8720a2fdc4f2                             0.50
# ...                                           ...
# nffcc1dbdf2212e6                             0.75
# nffd71b7f6a128df                             0.00
# nffde3b371d67394                             0.00
# nfff1a1111b35e84                             0.25
# nfff2bd38e397265                             0.00
#
#                   feature_unwonted_trusted_fixative  \
# id
# n003bba8a98662e4                               1.00
# n003bee128c2fcfc                               0.25
# n0048ac83aff7194                               0.75
# n00691bec80d3e02                               0.00
# n00b8720a2fdc4f2                               0.50
# ...                                             ...
# nffcc1dbdf2212e6                               0.75
# nffd71b7f6a128df                               0.00
# nffde3b371d67394                               0.75
# nfff1a1111b35e84                               1.00
# nfff2bd38e397265                               0.75
#
#                   feature_winsome_irreproachable_milkfish   era  data_type  \
# id
# n003bba8a98662e4                                     0.75  0001      train
# n003bee128c2fcfc                                     0.25  0001      train
# n0048ac83aff7194                                     0.25  0001      train
# n00691bec80d3e02                                     0.00  0001      train
# n00b8720a2fdc4f2                                     0.00  0001      train
# ...                                                   ...   ...        ...
# nffcc1dbdf2212e6                                     0.25  0574      train
# nffd71b7f6a128df                                     1.00  0574      train
# nffde3b371d67394                                     0.50  0574      train
# nfff1a1111b35e84                                     0.25  0574      train
# nfff2bd38e397265                                     0.50  0574      train
#
#                   target_nomi_20
# id
# n003bba8a98662e4            0.25
# n003bee128c2fcfc            0.75
# n0048ac83aff7194            0.50
# n00691bec80d3e02            0.75
# n00b8720a2fdc4f2            0.75
# ...                          ...
# nffcc1dbdf2212e6            0.75
# nffd71b7f6a128df            0.00
# nffde3b371d67394            0.25
# nfff1a1111b35e84            0.50
# nfff2bd38e397265            0.75
#
# [2412105 rows x 41 columns]

# %%
gc.collect()

print('Reading minimal features of validation and tournament data...')
validation_data = pd.read_parquet('validation_data.parquet',
                                  columns=read_columns)
tournament_data = pd.read_parquet(f'tournament_data_{current_round}.parquet',
                                  columns=read_columns)
nans_per_col = tournament_data[tournament_data["data_type"] == "live"].isna().sum()

# check for nans and fill nans
if nans_per_col.any():
    total_rows = len(tournament_data[tournament_data["data_type"] == "live"])
    print(f"Number of nans per column this week: {nans_per_col[nans_per_col > 0]}")
    print(f"out of {total_rows} total rows")
    print(f"filling nans with 0.5")
    tournament_data.loc[:, features] = tournament_data.loc[:, features].fillna(0.5)
else:
    print("No nans in the features this week!")
# Out:
# Reading minimal features of validation and tournament data...
# Number of nans per column this week: target_nomi_20    5350
# dtype: int64
# out of 5350 total rows
# filling nans with 0.5

# %%
validation_data
# Out:
#                   feature_agile_unrespited_gaucho  \
# id
# n000777698096000                             0.00
# n0009793a3b91c27                             1.00
# n00099ccd6698ab0                             0.25
# n0019e36bbb8702b                             0.25
# n0028cb874439df8                             0.50
# ...                                           ...
# nffbe5152c321f92                             0.00
# nffc011b4baa54c3                             0.25
# nffc12b2a846ab4e                             1.00
# nffc3c5ab0235de0                             1.00
# nffe714f0da4d819                             0.25
#
#                   feature_antichristian_slangiest_idyllist  \
# id
# n000777698096000                                      0.75
# n0009793a3b91c27                                      0.75
# n00099ccd6698ab0                                      1.00
# n0019e36bbb8702b                                      0.00
# n0028cb874439df8                                      0.75
# ...                                                    ...
# nffbe5152c321f92                                      0.50
# nffc011b4baa54c3                                      0.75
# nffc12b2a846ab4e                                      1.00
# nffc3c5ab0235de0                                      1.00
# nffe714f0da4d819                                      0.00
#
#                   feature_apomictical_motorized_vaporisation  \
# id
# n000777698096000                                        0.25
# n0009793a3b91c27                                        0.50
# n00099ccd6698ab0                                        1.00
# n0019e36bbb8702b                                        0.25
# n0028cb874439df8                                        0.75
# ...                                                      ...
# nffbe5152c321f92                                        0.00
# nffc011b4baa54c3                                        0.50
# nffc12b2a846ab4e                                        0.50
# nffc3c5ab0235de0                                        0.25
# nffe714f0da4d819                                        0.50
#
#                   feature_assenting_darn_arthropod  \
# id
# n000777698096000                              0.00
# n0009793a3b91c27                              0.25
# n00099ccd6698ab0                              0.50
# n0019e36bbb8702b                              1.00
# n0028cb874439df8                              0.50
# ...                                            ...
# nffbe5152c321f92                              0.50
# nffc011b4baa54c3                              0.50
# nffc12b2a846ab4e                              0.00
# nffc3c5ab0235de0                              1.00
# nffe714f0da4d819                              0.75
#
#                   feature_beery_somatologic_elimination  \
# id
# n000777698096000                                   0.50
# n0009793a3b91c27                                   0.25
# n00099ccd6698ab0                                   0.75
# n0019e36bbb8702b                                   0.00
# n0028cb874439df8                                   0.50
# ...                                                 ...
# nffbe5152c321f92                                   0.75
# nffc011b4baa54c3                                   0.00
# nffc12b2a846ab4e                                   0.00
# nffc3c5ab0235de0                                   0.75
# nffe714f0da4d819                                   0.50
#
#                   feature_bhutan_imagism_dolerite  \
# id
# n000777698096000                             0.25
# n0009793a3b91c27                             0.50
# n00099ccd6698ab0                             1.00
# n0019e36bbb8702b                             0.25
# n0028cb874439df8                             0.50
# ...                                           ...
# nffbe5152c321f92                             0.00
# nffc011b4baa54c3                             1.00
# nffc12b2a846ab4e                             1.00
# nffc3c5ab0235de0                             1.00
# nffe714f0da4d819                             0.25
#
#                   feature_branched_dilatory_sunbelt  \
# id
# n000777698096000                               0.00
# n0009793a3b91c27                               0.75
# n00099ccd6698ab0                               1.00
# n0019e36bbb8702b                               0.25
# n0028cb874439df8                               0.75
# ...                                             ...
# nffbe5152c321f92                               0.00
# nffc011b4baa54c3                               0.75
# nffc12b2a846ab4e                               0.75
# nffc3c5ab0235de0                               0.75
# nffe714f0da4d819                               0.00
#
#                   feature_buxom_curtained_sienna  \
# id
# n000777698096000                            0.00
# n0009793a3b91c27                            0.75
# n00099ccd6698ab0                            1.00
# n0019e36bbb8702b                            0.50
# n0028cb874439df8                            0.75
# ...                                          ...
# nffbe5152c321f92                            0.00
# nffc011b4baa54c3                            0.25
# nffc12b2a846ab4e                            0.75
# nffc3c5ab0235de0                            0.75
# nffe714f0da4d819                            0.00
#
#                   feature_cambial_bigoted_bacterioid  \
# id
# n000777698096000                                0.00
# n0009793a3b91c27                                0.50
# n00099ccd6698ab0                                0.25
# n0019e36bbb8702b                                0.50
# n0028cb874439df8                                1.00
# ...                                              ...
# nffbe5152c321f92                                1.00
# nffc011b4baa54c3                                0.50
# nffc12b2a846ab4e                                1.00
# nffc3c5ab0235de0                                0.50
# nffe714f0da4d819                                0.75
#
#                   feature_canalicular_peeling_lilienthal  ...  \
# id                                                        ...
# n000777698096000                                    0.50  ...
# n0009793a3b91c27                                    1.00  ...
# n00099ccd6698ab0                                    1.00  ...
# n0019e36bbb8702b                                    0.00  ...
# n0028cb874439df8                                    1.00  ...
# ...                                                  ...  ...
# nffbe5152c321f92                                    0.25  ...
# nffc011b4baa54c3                                    1.00  ...
# nffc12b2a846ab4e                                    1.00  ...
# nffc3c5ab0235de0                                    0.25  ...
# nffe714f0da4d819                                    0.75  ...
#
#                   feature_undivorced_unsatisfying_praetorium  \
# id
# n000777698096000                                        0.50
# n0009793a3b91c27                                        0.25
# n00099ccd6698ab0                                        0.25
# n0019e36bbb8702b                                        0.25
# n0028cb874439df8                                        1.00
# ...                                                      ...
# nffbe5152c321f92                                        0.00
# nffc011b4baa54c3                                        1.00
# nffc12b2a846ab4e                                        0.75
# nffc3c5ab0235de0                                        1.00
# nffe714f0da4d819                                        0.00
#
#                   feature_unforbidden_highbrow_kafir  \
# id
# n000777698096000                                0.50
# n0009793a3b91c27                                0.25
# n00099ccd6698ab0                                1.00
# n0019e36bbb8702b                                0.25
# n0028cb874439df8                                0.25
# ...                                              ...
# nffbe5152c321f92                                0.50
# nffc011b4baa54c3                                0.75
# nffc12b2a846ab4e                                1.00
# nffc3c5ab0235de0                                1.00
# nffe714f0da4d819                                0.25
#
#                   feature_univalve_abdicant_distrail  \
# id
# n000777698096000                                0.75
# n0009793a3b91c27                                0.75
# n00099ccd6698ab0                                0.00
# n0019e36bbb8702b                                0.50
# n0028cb874439df8                                0.25
# ...                                              ...
# nffbe5152c321f92                                0.00
# nffc011b4baa54c3                                0.75
# nffc12b2a846ab4e                                1.00
# nffc3c5ab0235de0                                0.75
# nffe714f0da4d819                                0.25
#
#                   feature_unsealed_suffixal_babar  \
# id
# n000777698096000                             0.00
# n0009793a3b91c27                             1.00
# n00099ccd6698ab0                             0.25
# n0019e36bbb8702b                             0.00
# n0028cb874439df8                             0.50
# ...                                           ...
# nffbe5152c321f92                             0.00
# nffc011b4baa54c3                             0.25
# nffc12b2a846ab4e                             0.75
# nffc3c5ab0235de0                             1.00
# nffe714f0da4d819                             0.50
#
#                   feature_unvaried_social_bangkok  \
# id
# n000777698096000                             0.50
# n0009793a3b91c27                             0.50
# n00099ccd6698ab0                             0.25
# n0019e36bbb8702b                             0.00
# n0028cb874439df8                             1.00
# ...                                           ...
# nffbe5152c321f92                             0.00
# nffc011b4baa54c3                             1.00
# nffc12b2a846ab4e                             0.75
# nffc3c5ab0235de0                             1.00
# nffe714f0da4d819                             0.25
#
#                   feature_unwonted_trusted_fixative  \
# id
# n000777698096000                               0.50
# n0009793a3b91c27                               0.50
# n00099ccd6698ab0                               1.00
# n0019e36bbb8702b                               0.00
# n0028cb874439df8                               0.75
# ...                                             ...
# nffbe5152c321f92                               0.00
# nffc011b4baa54c3                               0.25
# nffc12b2a846ab4e                               0.50
# nffc3c5ab0235de0                               1.00
# nffe714f0da4d819                               0.50
#
#                   feature_winsome_irreproachable_milkfish   era   data_type  \
# id
# n000777698096000                                     1.00  0857  validation
# n0009793a3b91c27                                     0.50  0857  validation
# n00099ccd6698ab0                                     0.25  0857  validation
# n0019e36bbb8702b                                     0.50  0857  validation
# n0028cb874439df8                                     0.00  0857  validation
# ...                                                   ...   ...         ...
# nffbe5152c321f92                                     0.50  0961  validation
# nffc011b4baa54c3                                     0.50  0961  validation
# nffc12b2a846ab4e                                     0.75  0961  validation
# nffc3c5ab0235de0                                     1.00  0961  validation
# nffe714f0da4d819                                     0.25  0961  validation
#
#                   target_nomi_20
# id
# n000777698096000            0.25
# n0009793a3b91c27            0.50
# n00099ccd6698ab0            0.00
# n0019e36bbb8702b            0.50
# n0028cb874439df8            0.50
# ...                          ...
# nffbe5152c321f92            0.50
# nffc011b4baa54c3            0.50
# nffc12b2a846ab4e            0.00
# nffc3c5ab0235de0            0.50
# nffe714f0da4d819            0.50
#
# [539658 rows x 41 columns]
