# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("/home/ralampay/Desktop/masks/000000017882.tiff", cv2.IMREAD_GRAYSCALE)

# %%
img.shape
# Out:
# (640, 480)

# %%
plt.imshow(img)
