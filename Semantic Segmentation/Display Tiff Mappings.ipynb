# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("/home/ralampay/Pictures/human-segmentation/tiff/23c2260d-ed90-4d0c-b2dd-f48a1560c888.tiff", cv2.IMREAD_GRAYSCALE)

# %%
img.shape
# Out:
# (441, 736)

# %%
plt.imshow(img)
